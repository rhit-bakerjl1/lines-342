# %% [markdown]
# # Example (Feature Engineering)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv('Monthly_Transportation_Statistics_modified.csv', sep=',')
df = df.dropna()
df.head()
# Out:
#    Index            Date  \
# 0    732   1/1/2008 0:00
# 1    735   4/1/2008 0:00
# 2    738   7/1/2008 0:00
# 3    741  10/1/2008 0:00
# 4    744   1/1/2009 0:00
#
#    Highway Fatalities Per 100 Million Vehicle Miles Traveled  \
# 0                                               1.22
# 1                                               1.25
# 2                                               1.33
# 3                                               1.32
# 4                                               1.09
#
#    Highway Fatalities  Transit Ridership - Other Transit Modes - Adjusted  \
# 0                8459                                           13911623
# 1                9435                                           15120273
# 2                9947                                           16530125
# 3                9582                                           16493417
# 4                7552                                           14517434
#
#    Transit Ridership - Fixed Route Bus - Adjusted  \
# 0                                       442844351
# 1                                       472743286
# 2                                       465258074
# 3                                       515540107
# 4                                       430468511
#
#    Transit Ridership - Urban Rail - Adjusted  Freight Rail Intermodal Units  \
# 0                                  348756976                         842973
# 1                                  387548619                         892452
# 2                                  394473975                         894970
# 3                                  404082236                         946084
# 4                                  347843528                         930248
#
#    Freight Rail Carloads  \
# 0                1238122
# 1                1326924
# 2                1264217
# 3                1315594
# 4                1294266
#
#    State and Local Government Construction Spending - Breakwater/Jetty  ...  \
# 0                                           50000000                    ...
# 1                                           37000000                    ...
# 2                                           69000000                    ...
# 3                                           75000000                    ...
# 4                                           38000000                    ...
#
#    Air Safety - Air Carrier Fatalities  \
# 0                                  0.0
# 1                                  0.0
# 2                                  1.0
# 3                                  0.0
# 4                                  0.0
#
#    U.S. Air Carrier Cargo (millions of revenue ton-miles) - International  \
# 0                                         1897167410
# 1                                         2184519616
# 2                                         1924038668
# 3                                         1959160995
# 4                                         1324523613
#
#    Truck tonnage index  \
# 0                 87.5
# 1                 86.6
# 2                 86.3
# 3                 82.9
# 4                 77.5
#
#    U.S. Air Carrier Cargo (millions of revenue ton-miles) - Domestic  \
# 0                                       1.168018e+09
# 1                                       1.230239e+09
# 2                                       1.176962e+09
# 3                                       1.182951e+09
# 4                                       9.331066e+08
#
#    Heavy truck sales SAAR (millions)  Light truck sales SAAR (millions)  \
# 0                             322000                            7963000
# 1                             337000                            6942000
# 2                             291000                            5692000
# 3                             267000                            4972000
# 4                             212000                            5001000
#
#    Auto sales SAAR (millions)  Transborder - Total North American Freight  \
# 0                     7420000                                7.558131e+10
# 1                     7326000                                8.635952e+10
# 2                     7023000                                8.607637e+10
# 3                     5694000                                8.449930e+10
# 4                     4572000                                5.426452e+10
#
#    Transborder - U.S. - Mexico Freight  Transborder - U.S. - Canada Freight
# 0                          28897924914                          46683386800
# 1                          31907991127                          54451524593
# 2                          33060251934                          53016122791
# 3                          34515941934                          49983355870
# 4                          22255716686                          32008803519
#
# [5 rows x 117 columns]

# %%
X = df.drop('Highway Fatalities Per 100 Million Vehicle Miles Traveled', axis = 1)
y=df.
# Out:
#   File "<ipython-input-11-793ffa41aea6>", line 2
#     y=df.'Highway Fatalities Per 100 Million Vehicle Miles Traveled'
#          ^
# SyntaxError: invalid syntax

# %%
#engineer interaction features
poly = PolynomialFeatures(2, interaction_only = True, include_bias = False)
Xe = poly.fit_transform(X)
cols = poly.get_feature_names(X.columns)
Xe = pd.DataFrame(Xe, columns = cols)
Xe.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  ...  \
# 0                 11.0                  34.0   0.9978  3.51       0.56  ...
# 1                 25.0                  67.0   0.9968  3.20       0.68  ...
# 2                 15.0                  54.0   0.9970  3.26       0.65  ...
#
#    total sulfur dioxide density  total sulfur dioxide pH  \
# 0                       33.9252                   119.34
# 1                       66.7856                   214.40
# 2                       53.8380                   176.04
#
#    total sulfur dioxide sulphates  total sulfur dioxide alcohol  density pH  \
# 0                           19.04                         319.6    3.502278
# 1                           45.56                         656.6    3.189760
# 2                           35.10                         529.2    3.250220
#
#    density sulphates  density alcohol  pH sulphates  pH alcohol  \
# 0           0.558768          9.37932        1.9656      32.994
# 1           0.677824          9.76864        2.1760      31.360
# 2           0.648050          9.77060        2.1190      31.948
#
#    sulphates alcohol
# 0              5.264
# 1              6.664
# 2              6.370
#
# [3 rows x 66 columns]

# %%
Xe = (Xe - Xe.mean())/Xe.std()

# %%
Xe['bias'] = 1
Xe.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# 1      -0.298454          1.966827    -1.391037        0.043403   0.223805
# 2      -0.298454          1.296660    -1.185699       -0.169374   0.096323
# 3       1.654339         -1.384011     1.483689       -0.453077  -0.264878
# 4      -0.528194          0.961576    -1.391037       -0.453077  -0.243630
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466047             -0.379014  0.558100  1.288240  -0.579025
# 1             0.872365              0.624168  0.028252 -0.719708   0.128910
# 2            -0.083643              0.228975  0.134222 -0.331073  -0.048074
# 3             0.107558              0.411372  0.664069 -0.978798  -0.461036
# 4            -0.466047             -0.379014  0.558100  1.288240  -0.579025
#
#    ...  total sulfur dioxide pH  total sulfur dioxide sulphates  \
# 0  ...                -0.318888                       -0.466169
# 1  ...                 0.567921                        0.583123
# 2  ...                 0.210063                        0.169262
# 3  ...                 0.336563                        0.157392
# 4  ...                -0.318888                       -0.466169
#
#    total sulfur dioxide alcohol  density pH  density sulphates  \
# 0                     -0.469886    1.330644          -0.575015
# 1                      0.535341   -0.727649           0.128665
# 2                      0.155323   -0.329450          -0.047314
# 3                      0.330716   -0.965278          -0.456379
# 4                     -0.469886    1.330644          -0.575015
#
#    density alcohol  pH sulphates  pH alcohol  sulphates alcohol  bias
# 0        -0.959307     -0.393794   -0.368454          -0.837776     1
# 1        -0.589072      0.003660   -0.756503          -0.110527     1
# 2        -0.587208     -0.104015   -0.616863          -0.263249     1
# 3        -0.577888     -0.644658   -0.849597          -0.619601     1
# 4        -0.959307     -0.393794   -0.368454          -0.837776     1
#
# [5 rows x 67 columns]

# %%
lr = LinearRegression(fit_intercept=False)
cv_results = cross_validate(lr, Xe, Y, return_train_score = True)
R2_train = cv_results['train_score'].mean()
R2_valid = cv_results['test_score'].mean()
print('Train R2', R2_train.round(2))
print('Validation R2', R2_valid.round(2))
# Out:
# Train R2 0.43
# Validation R2 0.25

# %%
lr.fit(Xe, Y)
coef = pd.Series(lr.coef_, index = Xe.columns)
coef.sort_values(ascending = False).head(10)
# Out:
# total sulfur dioxide           111.950530
# free sulfur dioxide density     89.493996
# sulphates                       64.908481
# chlorides density               59.382580
# citric acid density             30.382760
# residual sugar                  15.652508
# fixed acidity density           14.535287
# density pH                      12.773722
# density alcohol                  6.224390
# bias                             5.636023
# dtype: float64
